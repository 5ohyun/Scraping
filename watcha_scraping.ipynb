# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd


movie_list=[]

for i in range(1,42) :
    for a in range(12) : 
        headers = {
            'authority': 'api-pedia.watcha.com',
            'x-watcha-client-version': '2.0.0',
            'accept': 'application/vnd.frograms+json;version=20',
            'x-watcha-client-language': 'ko',
            'x-watcha-client': 'watcha-WebApp',
            'x-watcha-remote-addr': '220.95.42.18',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.135 Safari/537.36',
            'x-watcha-client-region': 'KR',
            'origin': 'https://pedia.watcha.com',
            'sec-fetch-site': 'same-site',
            'sec-fetch-mode': 'cors',
            'sec-fetch-dest': 'empty',
            'referer': 'https://pedia.watcha.com/ko-KR/decks/OphYTWVoSDLG',
            'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
            'cookie': '_gid=GA1.2.1288284538.1598411359; _c_drh=true; _gat=1; _ga=GA1.1.1510708654.1598411359; _ga_1PYHGTCRYW=GS1.1.1598453956.6.1.1598453957.0; _guinness_session=HTmyiVNRKA2%2F4ggJ9JeptWwQLTgSL0g%2F6HLRsr6UEr0Q34dqFuqllW%2FJ6SN%2FQCT%2Bgq%2F71bDA8kpJrqJAEVOZ1L7j--03K55p6s1bYAvYNc--XIK3xUCJNScVHNniJ9t46w%3D%3D',
            'if-none-match': 'W/"6123abad4d557be0c59df942d6345d8c"',
        }

        params = (
                ('page', i),
                ('size', '12'),
        )

        response = requests.get('https://api-pedia.watcha.com/api/decks/OphYTWVoSDLG/items', headers=headers, params=params)

        #NB. Original query string below. It seems impossible to parse and
        #reproduce query strings 100% accurately so the one below is given
        #in case the reproduced version is not "correct".
        # response = requests.get('https://api-pedia.watcha.com/api/decks/OphYTWVoSDLG/items?page=5&size=12', headers=headers)


        result_dict = json.loads(response.text)
        movieid = result_dict['result']['result'][a]['content']['code'] #[19]['user']
        title= result_dict['result']['result'][a]['content']['title']
        genres= result_dict['result']['result'][a]['content']['genres']
        movie_list.append([movieid, title, genres])
    
    print(movie_list)



#print(movie_list)

movie=pd.DataFrame(movie_list,columns=['movieid', 'title', 'genres'])
# Out:
#  '액션', '스릴러']], ['mW9GGZd', '최종병기 활', ['액션', '시대극', '전쟁']], ['mLOPPPO', '트랜스포머', ['액션', 'SF', '모험']], ['mWvDGZd', '써니', ['드라마', '코미디']], ['mP5mQx5', '화려한 휴가', ['드라마']], ['m5Qq28G', '스파이더맨: 홈커밍', ['액션', '모험', 'SF']], ['m5aVMGQ', '1987', ['드라마']], ['m5D2MDO', '베를린', ['스릴러', '액션']], ['mdBzraD', '마스터', ['범죄', '스릴러', '액션']], ['m5ZXBo0', '터널', ['드라마', '스릴러', '재난']], ['mOVgp1d', '어벤져스', ['모험', '판타지', '액션', 'SF']], ['mW4La3e', '내부자들', ['범죄', '드라마']], ['m5aVlap', '인천상륙작전', ['전쟁', '드라마']], ['mOAZ86G', '럭키', ['코미디']], ['mdjlyzW', '은밀하게 위대하게', ['액션', '드라마', '코미디']], ['mWLjVZD', '곡성(哭聲)', ['미스터리', '스릴러', '드라마']], ['mObG11N', '범죄도시', ['범죄', '액션']], ['m6dRLWy', '타짜', ['드라마', '코미디']], ['mr5ZNK5', '좋은 놈, 나쁜 놈, 이상한 놈', ['서부극', '코미디', '액션']], ['m5GvRKd', '늑대소년', ['로맨스', '판타지']], ['m5aVQDW', '미녀는 괴로워', ['코미디', '드라마']], ['mdMgK1o', '군함도', ['액션', '드라마']], ['m5xJNLq', '미션 임파서블: 폴아웃', ['액션', '스릴러', '모험']], ['mW4rmed', '다크 나이트 라이즈', ['액션', '범죄', '판타지', '스릴러']], ['m5ZXrxO', '아저씨', ['드라마', '액션', '범죄']], ['mO0g2Yx', '사도', ['시대극', '드라마', '역사']], ['mQO8nX5', '전우치', ['코미디', '액션', '판타지']], ['mO0gZ8X', '킹스맨 : 시크릿 에이전트', ['액션', '범죄', '코미디', '모험', '스릴러']], ['mOoJKyW', '미션 임파서블: 로그네이션', ['액션', '모험', '스릴러']], ['mWyP4V5', '투사부일체', ['코미디', '액션']], ['m5nAkVd', '연평해전', ['드라마']], ['m45ngDW', '반지의 제왕 : 왕의 귀환', ['판타지', '드라마', '액션', '전쟁', '모험']], ['mW4L2XW', '인셉션', ['액션', '모험', 'SF', '스릴러']], ['mdE09AO', '레미제라블', ['드라마', '역사', '로맨스', '전쟁']], ['md76wkO', '쉬리', ['액션', '드라마', '로맨스']], ['mWvkVBx', '캡틴 마블', ['액션', '모험', 'SF']], ['mjO0PzO', '미션 임파서블 3', ['액션', '모험', '스릴러']], ['mObG1vX', '쥬라기 월드: 폴른 킹덤', ['SF', '액션', '모험']], ['m5nQDa3', '청년경찰', ['액션']], ['m5DwGyd', '가문의 위기 - 가문의 영광 2', ['코미디']], ['mdReMLO', '숨바꼭질', ['스릴러']], ['m5xDyj5', '덕혜옹주', ['시대극', '드라마']], ['md7q6MW', '더 테러 라이브', ['드라마', '스릴러']], ['mdM3emW', '쥬라기 월드', ['액션', '모험', 'SF']], ['m5X6o4O', '감시자들', ['액션', '범죄', '스릴러']], ['mW93M4d', '의형제', ['드라마', '액션']], ['md7ZopO', '2012', ['SF', '액션', '재난', '모험']], ['mdMgNAJ', '앤트맨과 와스프', ['SF', '액션', '모험']], ['mdBzV9D', '닥터 스트레인지', ['액션', '모험', '판타지', 'SF']], ['mOVvgo8', '검은 사제들', ['스릴러', '드라마']], ['mOPoV8w', '안시성', ['시대극', '액션']], ['mWzw7oZ', '블랙 팬서', ['액션', '모험', 'SF']], ['md76ze8', '더 킹', ['범죄', '드라마']], ['m5X3JLd', '완득이', ['드라마', '코미디']], ['mOAR0Pd', '트랜스포머: 사라진 시대', ['액션', 'SF', '모험']], ['m5m1YNG', '완벽한 타인', ['코미디', '드라마']], ['mE5DYeW', '살인의 추억', ['범죄', '미스터리', '드라마', '스릴러']], ['m5Q9Zg8', '조커', ['스릴러', '드라마', '범죄']], ['mOkB6jW', '월드워Z', ['액션', '모험', '공포', 'SF', '스릴러']], ['mY5QVRW', '반지의 제왕 : 두 개의 탑', ['판타지', '드라마', '액션', '모험']], ['mO2N00O', '타워', ['재난', '드라마']], ['mAd7YNW', '말아톤', ['스포츠', '드라마']], ['mOAZ8QZ', '미녀와 야수', ['가족', '판타지', '로맨스']], ['mAd7k2d', '추격자', ['범죄', '액션', '스릴러']], ['mWLjDm6', '독전', ['범죄', '액션']], ['m5n07VO', '쿵푸팬더 2', ['애니메이션', '판타지', '가족', '모험', '액션', '코미디']], ['mWqJbZX', '아쿠아맨', ['액션', 'SF', '모험', '판타지']], ['mdRLQZ4', '공작', ['드라마']], ['mdEwAR2', '인사이드 아웃', ['코미디', '가족', '드라마', '판타지', '애니메이션', '모험']], ['mOo0Pzd', '캐리비안의 해적 - 세상의 끝에서', ['액션', '판타지', '모험']], ['mOVvVxY', '킹스맨: 골든 서클', ['액션', '모험', '코미디']], ['mr5Z8RO', '동갑내기 과외하기', ['로맨틱코미디']], ['mgOA3E5', '스파이더맨 3', ['액션', '모험', 'SF', '판타지']], ['m5Zo00W', '바람과 함께 사라지다', ['시대극', '액션', '코미디', '역사']], ['mWwBVzq', '마션', ['모험', '드라마', 'SF']], ['mdBzrpD', '토르: 라그나로크', ['액션', '판타지', '코미디', 'SF', '모험']], ['mdR7xv5', '어메이징 스파이더맨', ['액션', 'SF', '모험', '판타지']], ['mWyJQmV', '님아, 그 강을 건너지 마오', ['다큐멘터리']], ['md7r0l1', '봉오동 전투', ['액션', '드라마']], ['mWJvZRW', '조선명탐정 : 각시투구꽃의 비밀', ['코미디', '액션']], ['mOlR8n5', '군도:민란의 시대', ['액션', '시대극']], ['mdKD2aV', '남산의 부장들', ['드라마']], ['m5ZZ2P9', '라이온 킹', ['모험', '가족', '드라마']], ['mWv1lb5', '범죄와의 전쟁 : 나쁜놈들 전성시대', ['액션', '범죄', '드라마']], ['mOgBxPa', '주토피아', ['모험', '애니메이션', '액션', '코미디', '가족', '키즈']], ['mWyQz6W', '엣지 오브 투모로우', ['액션', 'SF', '모험']], ['m5e8v3d', '신세계', ['드라마', '범죄', '액션']], ['mOk6qjW', '쿵푸팬더', ['애니메이션', '가족', '모험', '액션', '코미디']], ['mW93GDZ', '신비한 동물사전', ['가족', '모험', '판타지']], ['m5xAwjW', '도가니', ['스릴러', '드라마']], ['mdEww2W', '캐리비안의 해적 - 망자의 함', ['스릴러', '모험', '판타지', '액션']], ['m5NVoR5', '박 ...

# %%
movie.to_csv('watcha_movie_list.csv',encoding='euc-kr',index=False)

    # with open('data.json', 'a', encoding='UTF-8') as outfile:
    #     json.dump(result_dict, outfile, ensure_ascii=False)

# %%
movie
# Out:
#      movieid               title                        genres
# 0    mWzM9D5                  명량            [전쟁, 드라마, 시대극, 액션]
# 1    mdMBlkR                극한직업                         [코미디]
# 2    mWw8zEO           신과함께-죄와 벌                    [판타지, 드라마]
# 3    mdReBLO                국제시장                         [드라마]
# 4    mdBzNnP          어벤져스: 엔드게임                  [액션, 모험, SF]
# ..       ...                 ...                           ...
# 487  mjO0k7W            아내가 결혼했다                 [드라마, 로맨틱코미디]
# 488  mWpmGjx             저스티스 리그             [판타지, 액션, SF, 모험]
# 489  m5xMAEW    여고괴담 세번째이야기 여우계단                          [공포]
# 490  mLOPkXW              아이, 로봇  [스릴러, SF, 미스터리, 드라마, 범죄, 액션]
# 491  mXOg4Nd  벤자민 버튼의 시간은 거꾸로 간다               [판타지, 로맨스, 드라마]
#
# [492 rows x 3 columns]
